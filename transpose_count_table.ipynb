# %%
import pandas as pd
# Out:
# /Users/jim/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('../bc_counts.csv', header=0, index_col=0)
df.T.to_csv('../bc_counts_transposed.csv', header=True, index=True)
